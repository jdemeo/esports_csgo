# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from os import listdir
from os.path import join

import matplotlib.style as style
style.use('fivethirtyeight')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Player Level Analysis

# %%
path = '../data/master_players'
files = listdir(path)

# Import data
player_df = pd.DataFrame()
for file in files:
    file_df = pd.read_csv(os.path.join(path, file))
    player_df = player_df.append(file_df, ignore_index=True, sort=False)
    
# Convert unix time stamp to date time
player_df['date'] = player_df['date'] / 1000
player_df['date'] = pd.to_datetime(player_df['date'], unit ='s')
    
# Consider historical from 2018 to present
player_df = player_df.loc[player_df['date'] >= '2019-01-01 00:00:00', :]

# Keep only date
player_df['date'] = player_df['date'].dt.date

# Drop rows with NaN in KAST or ADR
player_df = player_df.loc[-player_df['KAST'].isna(), :]
player_df = player_df.loc[-player_df['ADR'].isna(), :]
player_df.reset_index(drop=True, inplace=True)
    
print(player_df.shape)
player_df.tail()
# Out:
# (93229, 20)
#        map_id      map        date  team_id    team_name  player_id  \
# 93224   90598     nuke  2019-08-22     8680  Lucid Dream      12564
# 93225   90599      ovp  2019-08-22     6922     Corvidae      14689
# 93226   90600      inf  2019-08-22     7865         HAVU       9271
# 93227   90602  vertigo  2019-08-22     8680  Lucid Dream      13461
# 93228   90603      mrg  2019-08-22     6922     Corvidae      16034
#
#       player_name  kills  hs_kills  assists  flash_assists  deaths  KAST  \
# 93224     Geniuss     12         5        2              0      18  58.3
# 93225       nibke     11         6        9              2      22  76.7
# 93226       sLowi     31        18        3              2      28  64.3
# 93227    wannafly     12         9        4              0      23  72.4
# 93228       Dirty      9         4        8              2      21  60.7
#
#        kill_death_diff   ADR  first_kills_diff  rating  kills_per_round  \
# 93224               -6  52.5                 0    0.73             0.50
# 93225              -11  59.4                -1    0.88             0.37
# 93226                3  67.1                -2    1.02             0.74
# 93227              -11  57.2                -1    0.75             0.41
# 93228              -12  60.7                -3    0.70             0.32
#
#        deaths_per_round  impact
# 93224              0.75    0.63
# 93225              0.73    0.73
# 93226              0.67    1.11
# 93227              0.79    0.47
# 93228              0.75    0.58

# %% [markdown]
# To rank player performance I will consider how a particular player has played most recently and also consider how a player has matched up against a particular opponent.
#
# Exponential Decay:
# - y = a(1 - r)^x
# - a = initial value (the amount before measuring growth or decay)
# - r = growth or decay rate (most often represented as a percentage and expressed as a decimal)
# - x = number of time intervals that have passed

# %% [markdown]
# #### Feature Engineering

# %%
# Number of days from today
current_datetime = pd.Timestamp('today').date()
player_df['days_from_today'] = (current_datetime - player_df['date']) / np.timedelta64(1, 'D')

# Exponential Decay from today
def exp_decay(days, a=1, r=0.03):
    '''
    @days: days from today
    @a: initial value
    @r: decay rate
    '''
    return a * (1 - r) ** days

player_df['decay'] = player_df['days_from_today'].apply(exp_decay)

# Normalize decay on a per player basis
player_df['normalized_decay'] = player_df['decay'] / player_df.groupby('player_id')['decay'].transform('sum')

player_df.head()
# Out:
#    map_id  map        date  team_id   team_name  player_id player_name  kills  \
# 0   79922  inf  2019-01-04     8248        PACT      16847         mhL     18
# 1   79923  mrg  2019-01-04     8248        PACT      16847         mhL     19
# 2   79924   d2  2019-01-04     7535   ROG SPUNJ      11789      Misfit     15
# 3   79925  mrg  2019-01-04     9791  ROG pronax      17082      Ex6poN     21
# 4   79926  cch  2019-01-04     8695   ROG nooky      18457       s1las     20
#
#    hs_kills  assists  flash_assists  deaths  KAST  kill_death_diff   ADR  \
# 0         9        1              0      16  63.0                2  74.5
# 1        12        4              0      17  64.0                2  79.6
# 2         6        3              1      17  58.3               -2  70.1
# 3         9        1              0      19  65.4                2  71.0
# 4        11        5              0      20  79.2                0  91.4
#
#    first_kills_diff  rating  kills_per_round  deaths_per_round  impact  \
# 0                 4    1.14             0.67              0.59    1.41
# 1                -2    1.08             0.76              0.68    1.05
# 2                 0    0.94             0.62              0.71    0.99
# 3                 0    1.09             0.81              0.73    1.30
# 4                 1    1.17             0.83              0.83    1.10
#
#    days_from_today     decay  normalized_decay
# 0            230.0  0.000907          0.000256
# 1            230.0  0.000907          0.000256
# 2            230.0  0.000907          0.326599
# 3            230.0  0.000907          0.244332
# 4            230.0  0.000907          0.162479

# %%
# Aggregation on features with exponential decay to get current state of player
def player_features_normalized(stuff):
    new_df = pd.DataFrame()
    new_df['map_id'] = stuff['map_id']
    new_df['map'] = stuff['map']
    new_df['team_id'] = stuff['team_id']
    new_df['team_name'] = stuff['team_name']
    new_df['player_id'] = stuff['player_id']
    new_df['player_name'] = stuff['player_name']
    
    # Normalize features of interest
    columns = ['kills', 'assists', 'deaths', 'ADR', 'rating']
    for column in columns:
        new_df[column] = stuff[column] * stuff['normalized_decay']
    
    return new_df

player_norm_df = player_features_normalized(player_df)
player_norm_df.head()
# Out:
#    map_id  map  team_id   team_name  player_id player_name     kills  \
# 0   79922  inf     8248        PACT      16847         mhL  0.004608
# 1   79923  mrg     8248        PACT      16847         mhL  0.004864
# 2   79924   d2     7535   ROG SPUNJ      11789      Misfit  4.898990
# 3   79925  mrg     9791  ROG pronax      17082      Ex6poN  5.130982
# 4   79926  cch     8695   ROG nooky      18457       s1las  3.249581
#
#     assists    deaths        ADR    rating
# 0  0.000256  0.004096   0.019070  0.000292
# 1  0.001024  0.004352   0.020376  0.000276
# 2  0.979798  5.552189  22.894613  0.307003
# 3  0.244332  4.642317  17.347607  0.266322
# 4  0.812395  3.249581  14.850586  0.190101

# %% [markdown]
# So from these normalized features, I would like to create a custom player score to rank the best players.

# %%
# Create 'true' features counts (sum up a feature)
player_norm_df['true_kills'] = player_norm_df.groupby('player_id')['kills'].transform('sum')
player_norm_df['true_assists'] = player_norm_df.groupby('player_id')['assists'].transform('sum')
player_norm_df['true_deaths'] = player_norm_df.groupby('player_id')['deaths'].transform('sum')
player_norm_df['true_ADR'] = player_norm_df.groupby('player_id')['ADR'].transform('sum')
player_norm_df['true_rating'] = player_norm_df.groupby('player_id')['rating'].transform('sum')
player_norm_df['true_rating'].hist()
plt.show()

# %%
# Collect only the player and their 'true' features
true_player_df = player_norm_df.drop(columns=['map_id', 'map', 'kills', 'assists', 'deaths', 'ADR', 'rating']).drop_duplicates()
print(true_player_df.shape)
true_player_df.head()
# Out:
# (5679, 9)
#    team_id   team_name  player_id player_name  true_kills  true_assists  \
# 0     8248        PACT      16847         mhL   21.631406      4.170600
# 2     7535   ROG SPUNJ      11789      Misfit   13.653199      1.989899
# 3     9791  ROG pronax      17082      Ex6poN   17.221662      3.267003
# 4     8695   ROG nooky      18457       s1las   15.812395      5.000000
# 5     7538    ROG fl0m       8503        fl0m   18.001647      5.117473
#
#    true_deaths   true_ADR  true_rating
# 0    18.234292  82.109163     1.175768
# 2    16.663300  63.332323     0.892862
# 3    17.236776  70.496222     1.019471
# 4    17.654941  68.485427     1.039347
# 5    16.117996  75.785734     1.102225

# %% [markdown]
# ### StarLadder Major 2019 - CHALLENGERS STAGE
#
# So just as a review, we are looking at players weighted average kills, assists, deaths, and ADR from the past year. This was determined by exponentially decaying on their performanes. Essentially giving more weight to recent games than older games. From these features, I hope to be able to rank players reasonably well and also optimize against the fantasy leagues constraints (max: 1,000,000 USD team composition, player values [ex: 'Stewie2K' = 202,000 USD])

# %%
team_names = ['Vitality', 'NRG', 'G2', 'FURIA', 'mousesports', 'North', 'CR4ZY', 'forZe', 
              'Grayhound', 'AVANGAR', 'Complexity', 'HellRaisers', 'INTZ', 'TYLOO', 'DreamEaters', 'Syman']

tourny_players = true_player_df.loc[true_player_df['team_name'].isin(team_names), :]
print(tourny_players.shape)
tourny_players.head()
# Out:
# (113, 9)
#      team_id team_name  player_id player_name  true_kills  true_assists  \
# 48      9565  Vitality       7322        apEX   17.205124      5.462769
# 56      9565  Vitality       7168        NBK-   18.060151      4.550673
# 72      8135     forZe       8726   facecrack   19.278443      4.315448
# 77      8135     forZe      12733    xsepower   19.740176      4.069722
# 224     8120   AVANGAR      11942      buster   17.743899      4.325380
#
#      true_deaths   true_ADR  true_rating
# 48     18.162018  73.483533     1.015571
# 56     18.957018  78.586320     1.068443
# 72     18.423463  79.427885     1.146886
# 77     15.001570  74.715680     1.245796
# 224    15.366281  73.601862     1.141103

# %%
tourny_players['team_name'].value_counts()
# Out:
# Syman          11
# HellRaisers    11
# INTZ           10
# mousesports     8
# AVANGAR         7
# Grayhound       7
# NRG             7
# TYLOO           7
# DreamEaters     6
# forZe           6
# North           6
# FURIA           6
# G2              6
# CR4ZY           5
# Complexity      5
# Vitality        5
# Name: team_name, dtype: int64

# %%
esl_one_players.sort_values(['true_rating'], ascending=False)
# Out:
#        team_id    team_name  player_id  player_name  true_kills  true_assists  \
# 9697      8008    Grayhound      12591     sterling   20.321904      3.357883
# 2370      8008    Grayhound       9102         Sico   19.510580      4.799729
# 2961      4863        TYLOO       8605     somebody   21.442606      3.923235
# 227       8120      AVANGAR      13776         Jame   20.954197      3.237031
# 233       9565     Vitality      11893        ZywOo   21.572376      5.220686
# 1376      4863        TYLOO       7131        BnTeT   19.356539      6.187225
# 6949     10150        CR4ZY       3972       huNter   21.017917      5.098727
# 6775     10150        CR4ZY       9618         nexa   20.398855      5.226925
# 2364      8008    Grayhound      11141       erkaSt   20.170461      4.144949
# 4398      6619         INTZ       8513          yay   20.687157      3.618666
# 77        8135        forZe      12733     xsepower   19.740176      4.069722
# 370       8008    Grayhound       9115       dexter   19.695889      4.083254
# 380       6673          NRG       9136       Brehze   20.886424      4.075945
# 2328     17.737559  70.075787     1.010434
# 5416     17.850424  71.966068     1.010176
# 31953    18.114639  72.337043     1.008566
# 6582     18.230652  74.271242     1.007843
# 5006     15.785779  60.967526     1.002041
# 45304    15.535567  61.544920     0.997241
# 26103    17.799566  68.863678     0.990608
# 92570    18.586246  72.100293     0.990147
# 230      18.586246  72.100293     0.990147
# 7479     17.087246  69.675083     0.988077
# 985      17.710368  67.440350     0.980464
# 543      16.531184  63.334698     0.980134
# 17601    17.697497  69.872840     0.980031
# 1372     18.019341  67.451747     0.975629
# 1219     16.943966  66.330880     0.972974
# 228      17.804743  68.927032     0.966500
# 10144    17.726822  70.289419     0.966285
# 14087    19.173622  70.775878     0.963133
# 4737     17.700910  66.662965     0.957001
# 67920    19.350923  73.374943     0.954989
# 18480    18.611343  67.998694     0.947158
# 783      18.611343  67.998694     0.947158
# 1527     17.627748  60.677811     0.887837
# 12134    19.275978  63.634679     0.881811
# 811      20.373104  66.732376     0.878593
# 46442    20.265038  62.275821     0.862092
# 2042     20.265038  62.275821     0.862092
# 66311    20.000000  41.700000     0.580000
# 80894    15.553299  34.538071     0.563249

# %% [markdown]
# ### Considerations only data where teams have played each other

# %%
path = '../data/master_players'
files = listdir(path)

# Import data
player_df = pd.DataFrame()
for file in files:
    file_df = pd.read_csv(os.path.join(path, file))
    player_df = player_df.append(file_df, ignore_index=True, sort=False)
    
# Convert unix time stamp to date time
player_df['date'] = player_df['date'] / 1000
player_df['date'] = pd.to_datetime(player_df['date'], unit ='s')
    
# Consider historical from 2018 to present
player_df = player_df.loc[player_df['date'] >= '2019-01-01 00:00:00', :]

# Keep only date
player_df['date'] = player_df['date'].dt.date

# Drop rows with NaN in KAST or ADR
player_df = player_df.loc[-player_df['KAST'].isna(), :]
player_df = player_df.loc[-player_df['ADR'].isna(), :]
player_df.reset_index(drop=True, inplace=True)
    
print(player_df.shape)
player_df.tail()
# Out:
# (93229, 20)
#        map_id      map        date  team_id    team_name  player_id  \
# 93224   90598     nuke  2019-08-22     8680  Lucid Dream      12564
# 93225   90599      ovp  2019-08-22     6922     Corvidae      14689
# 93226   90600      inf  2019-08-22     7865         HAVU       9271
# 93227   90602  vertigo  2019-08-22     8680  Lucid Dream      13461
# 93228   90603      mrg  2019-08-22     6922     Corvidae      16034
#
#       player_name  kills  hs_kills  assists  flash_assists  deaths  KAST  \
# 93224     Geniuss     12         5        2              0      18  58.3
# 93225       nibke     11         6        9              2      22  76.7
# 93226       sLowi     31        18        3              2      28  64.3
# 93227    wannafly     12         9        4              0      23  72.4
# 93228       Dirty      9         4        8              2      21  60.7
#
#        kill_death_diff   ADR  first_kills_diff  rating  kills_per_round  \
# 93224               -6  52.5                 0    0.73             0.50
# 93225              -11  59.4                -1    0.88             0.37
# 93226                3  67.1                -2    1.02             0.74
# 93227              -11  57.2                -1    0.75             0.41
# 93228              -12  60.7                -3    0.70             0.32
#
#        deaths_per_round  impact
# 93224              0.75    0.63
# 93225              0.73    0.73
# 93226              0.67    1.11
# 93227              0.79    0.47
# 93228              0.75    0.58

# %%
# Subset dataframe by maps where only the teams in the tournament have played each other
team_names = ['Vitality', 'NRG', 'G2', 'FURIA', 'mousesports', 'North', 'CR4ZY', 'forZe', 
              'Grayhound', 'AVANGAR', 'Complexity', 'HellRaisers', 'INTZ', 'TYLOO', 'DreamEaters', 'Syman']

# Only data from the teams of interest
player_df = player_df.loc[player_df['team_name'].isin(team_names),:]

# Find map_ids that are shared between teams
shared_ids = []
all_ids = []
for team in team_names:
    team_df = player_df.loc[player_df['team_name'] == team, :]
    map_ids = list(team_df['map_id'].unique())

    # Check if map_id has already been collected
    for map_id in map_ids:
        if map_id in all_ids:
            shared_ids.append(map_id)
            
    all_ids = all_ids + list(map_ids)
    
print('Number of matches between all teams:', len(shared_ids))

# Collect only matches between teams in the tourny
player_df = player_df.loc[player_df['map_id'].isin(shared_ids),:]
player_df.head()
# Out:
# Number of matches between all teams: 201
#      map_id   map        date  team_id team_name  player_id player_name  \
# 304   80267  nuke  2019-01-18     9565  Vitality      11893       ZywOo
# 307   80270    d2  2019-01-18     9565  Vitality       7168        NBK-
# 333   80299   mrg  2019-01-20     9565  Vitality      11893       ZywOo
# 334   80300  nuke  2019-01-20     9565  Vitality      11893       ZywOo
# 337   80303   inf  2019-01-20     9565  Vitality       7168        NBK-
#
#      kills  hs_kills  assists  flash_assists  deaths  KAST  kill_death_diff  \
# 304     28        10        1              0      21  83.3                7
# 307     17        15        3              1      20  57.1               -3
# 333     22        10        4              0      17  78.6                5
# 334     25         7        5              0       7  81.0               18
# 337     22        13        5              2      11  87.5               11
#
#        ADR  first_kills_diff  rating  kills_per_round  deaths_per_round  \
# 304   80.0                 5    1.34             0.93              0.70
# 307   72.5                 0    1.06             0.61              0.71
# 333   87.1                 6    1.34             0.79              0.61
# 334  121.1                 2    1.97             1.19              0.33
# 337   85.3                 4    1.50             0.92              0.46
#
#      impact
# 304    1.33
# 307    1.23
# 333    1.52
# 334    2.18
# 337    1.38

# %%
team = 'G2'
player_df[(player_df['team_name'] == team) &
          (player_df['map_id'].isin(shared_ids))]['map_id'].unique()
# Out:
# array([81084, 81090, 81098, 81471, 81551, 81554, 81557, 83221, 83229,
#        85822, 85824, 88009, 88012, 88016, 88145, 83328, 83332, 84444,
#        84448, 84451, 86862, 86866, 86869, 87925, 87940, 88154, 88159,
#        88165, 88340, 88343, 88348, 88914, 88919, 88925])

# %%
player_df[player_df['map_id'].isin([86890])].sort_values(by=['team_name', 'rating'], ascending=False)
# Out:
# Empty DataFrame
# Columns: [map_id, map, date, team_id, team_name, player_id, player_name, kills, hs_kills, assists, flash_assists, deaths, KAST, kill_death_diff, ADR, first_kills_diff, rating, kills_per_round, deaths_per_round, impact]
# Index: []

# %%
p1 = 'shox'
p2 = 'JaCkz'

plt.scatter(player_df.loc[player_df['player_name'] == p1, 'days_from_today'], player_df.loc[player_df['player_name'] == p1, 'rating'].values, label=p1)
plt.scatter(player_df.loc[player_df['player_name'] == p2, 'days_from_today'], player_df.loc[player_df['player_name'] == p2, 'rating'].values, label=p2)
plt.legend()
plt.show()

# %%
player_df.loc[player_df['player_name'] == 'jks', :]
# Out:
# datetime.date(2019, 7, 14)

# %%
player_df['date'].max()
# Out:
# datetime.date(2019, 7, 14)

# %%
# Number of days from today
current_datetime = pd.Timestamp('today').date()
player_df['days_from_today'] = (current_datetime - player_df['date']) / np.timedelta64(1, 'D')

# Exponential Decay from today
def exp_decay(days, a=1, r=0.03):
    '''
    @days: days from today
    @a: initial value
    @r: decay rate
    '''
    return a * (1 - r) ** days

player_df['decay'] = player_df['days_from_today'].apply(exp_decay)

# Normalize decay on a per player basis
player_df['normalized_decay'] = player_df['decay'] / player_df.groupby('player_id')['decay'].transform('sum')

player_df.head()
# Out:
#      map_id   map        date  team_id team_name  player_id player_name  \
# 304   80267  nuke  2019-01-18     9565  Vitality      11893       ZywOo
# 307   80270    d2  2019-01-18     9565  Vitality       7168        NBK-
# 333   80299   mrg  2019-01-20     9565  Vitality      11893       ZywOo
# 334   80300  nuke  2019-01-20     9565  Vitality      11893       ZywOo
# 337   80303   inf  2019-01-20     9565  Vitality       7168        NBK-
#
#      kills  hs_kills  assists  flash_assists  deaths  KAST  kill_death_diff  \
# 304     28        10        1              0      21  83.3                7
# 307     17        15        3              1      20  57.1               -3
# 333     22        10        4              0      17  78.6                5
# 334     25         7        5              0       7  81.0               18
# 337     22        13        5              2      11  87.5               11
#
#        ADR  first_kills_diff  rating  kills_per_round  deaths_per_round  \
# 304   80.0                 5    1.34             0.93              0.70
# 307   72.5                 0    1.06             0.61              0.71
# 333   87.1                 6    1.34             0.79              0.61
# 334  121.1                 2    1.97             1.19              0.33
# 337   85.3                 4    1.50             0.92              0.46
#
#      impact  days_from_today     decay  normalized_decay
# 304    1.33            216.0  0.001389          0.000464
# 307    1.23            216.0  0.001389          0.000464
# 333    1.52            214.0  0.001476          0.000493
# 334    2.18            214.0  0.001476          0.000493
# 337    1.38            214.0  0.001476          0.000493

# %%
# Aggregation on features with exponential decay to get current state of player
def player_features_normalized(stuff):
    new_df = pd.DataFrame()
    new_df['map_id'] = stuff['map_id']
    new_df['map'] = stuff['map']
    new_df['team_id'] = stuff['team_id']
    new_df['team_name'] = stuff['team_name']
    new_df['player_id'] = stuff['player_id']
    new_df['player_name'] = stuff['player_name']
    
    
    # Normalize features of interest
    columns = ['kills', 'assists', 'deaths', 'ADR', 'rating']
    for column in columns:
        new_df[column] = stuff[column] * stuff['normalized_decay']
    
    return new_df

player_norm_df = player_features_normalized(player_df)
player_norm_df.head()
# Out:
#      map_id   map  team_id team_name  player_id player_name     kills  \
# 304   80267  nuke     9565  Vitality      11893       ZywOo  0.012982
# 307   80270    d2     9565  Vitality       7168        NBK-  0.007882
# 333   80299   mrg     9565  Vitality      11893       ZywOo  0.010841
# 334   80300  nuke     9565  Vitality      11893       ZywOo  0.012320
# 337   80303   inf     9565  Vitality       7168        NBK-  0.010841
#
#       assists    deaths       ADR    rating
# 304  0.000464  0.009737  0.037093  0.000621
# 307  0.001391  0.009273  0.033615  0.000491
# 333  0.001971  0.008377  0.042921  0.000660
# 334  0.002464  0.003449  0.059676  0.000971
# 337  0.002464  0.005421  0.042034  0.000739

# %%
# Create 'true' features counts (sum up a feature)
player_norm_df['true_kills'] = player_norm_df.groupby('player_id')['kills'].transform('sum')
player_norm_df['true_assists'] = player_norm_df.groupby('player_id')['assists'].transform('sum')
player_norm_df['true_deaths'] = player_norm_df.groupby('player_id')['deaths'].transform('sum')
player_norm_df['true_ADR'] = player_norm_df.groupby('player_id')['ADR'].transform('sum')
player_norm_df['true_rating'] = player_norm_df.groupby('player_id')['rating'].transform('sum')
player_norm_df['true_rating'].hist()
plt.show()

# %%
# Collect only the player and their 'true' features
true_player_df = player_norm_df.drop(columns=['map_id', 'map', 'kills', 'assists', 'deaths', 'ADR', 'rating']).drop_duplicates()
print(true_player_df.shape)
true_player_df.head()
# Out:
# (100, 9)
#      team_id team_name  player_id player_name  true_kills  true_assists  \
# 304     9565  Vitality      11893       ZywOo   20.519711      5.505336
# 307     9565  Vitality       7168        NBK-   15.185090      3.988338
# 458     8297     FURIA      12521         arT   18.641248      4.218369
# 463     8297     FURIA      15631    KSCERATO   17.728060      4.139200
# 466     8297     FURIA      12822        VINI   15.235255      4.750707
#
#      true_deaths   true_ADR  true_rating
# 304    15.693266  87.624817     1.333113
# 307    17.858791  68.303324     0.933562
# 458    18.399036  76.898856     1.092819
# 463    15.259107  74.064403     1.092934
# 466    17.819817  68.785818     0.973370

# %%
# Rank by rating
true_player_df.sort_values(['true_rating'], ascending=False).reset_index(drop=True)
# Out:
#     team_id    team_name  player_id  player_name  true_kills  true_assists  \
# 0      8135        forZe      12733     xsepower   20.626344      3.863377
# 1      9565     Vitality      11893        ZywOo   20.519711      5.505336
# 2     10150        CR4ZY       9618         nexa   22.191473      5.435258
# 3      4863        TYLOO       7131        BnTeT   22.549832      4.350400
# 4      5995           G2       8374        bodyy   18.352686      6.234652
# 5      8135        forZe      11654      almazer   19.745278      3.885889
# 6      8135        forZe      12732         FL1T   19.546701      5.339674
# 7      8135        forZe       8726    facecrack   19.885677      3.833771
# 8      6673          NRG       9136       Brehze   22.224664      3.889708
# 9      5995           G2       7167       kennyS   21.786227      5.982109
# 10     4494  mousesports       9960       frozen   18.860214      4.139448
# 11    10150        CR4ZY       3972       huNter   19.772902      5.262482
# 12     8135        forZe      13157        Jerry   17.704777      5.402772
# 13     8297        FURIA      12553       yuurih   19.903902      4.282968
# 14     8305  DreamEaters      12027         Krad   22.411373      5.658933
# 15     4863        TYLOO       7028       Summer   21.872716      2.705679
# 16     8305  DreamEaters      12016        svyat   21.657575      5.899298
# 17    10150        CR4ZY      12030    EspiranTo   18.493468      4.602300
# 18     5005   Complexity       7810      ShahZaM   20.959596      1.989899
# 19     8120      AVANGAR      13239       qikert   19.896938      3.856292
# 20     8305  DreamEaters      13982     Forester   22.340422      4.610009
# 21     6673          NRG      11219         CeRq   18.902721      4.275069
# 22     4863        TYLOO       8605     somebody   21.202580      4.354170
# 23    10150        CR4ZY      11283       ottoNd   17.155455      3.891096
# 24     8297        FURIA       6547       guerri   14.000000      1.500000
# 25     4494  mousesports      11816         ropz   16.835345      3.141182
# 26     9565     Vitality       7322         apEX   18.361658      4.613849
# 27     4494  mousesports       2730       chrisJ   17.920754      2.888504
# 51    18.394062  72.821824     1.010362
# 52    17.084311  68.901616     1.006727
# 53    16.636618  72.072636     1.006604
# 54    18.825778  68.535195     1.003085
# 55    19.166523  71.354568     0.992522
# 56    19.346801  75.056229     0.990909
# 57    17.000000  70.400000     0.990000
# 58    17.715893  71.386200     0.984526
# 59    17.271167  66.018348     0.979414
# 60    20.239774  68.700379     0.978909
# 61    18.691196  68.332761     0.978752
# 62    17.819817  68.785818     0.973370
# 63    16.939694  66.469875     0.971264
# 64    16.462375  61.530361     0.963880
# 65    20.831566  69.738456     0.946273
# 66    18.333388  72.658100     0.942695
# 67    16.081787  70.397882     0.934188
# 68    17.858791  68.303324     0.933562
# 69    19.279800  61.369517     0.924732
# 70    18.348859  65.301770     0.924531
# 71    18.429711  65.660463     0.920400
# 72    19.670334  58.211295     0.915162
# 73    18.418418  70.223632     0.914763
# 74    19.210572  68.290444     0.914367
# 75    15.838487  60.754348     0.902516
# 76    17.320000  65.394021     0.899726
# 77    19.155379  61.169273     0.890369
# 78    17.687694  59.607000     0.888497
# 79    18.217471  64.653811     0.885578
# 80    18.217471  64.653811     0.885578
# 81    18.931708  67.748739     0.880293
# 82    18.555510  70.395504     0.873251
# 83    20.683502  64.766330     0.871818
# 84    22.000000  56.500000     0.870000
# 85    16.456117  59.993532     0.860158
# 86    19.679685  62.329586     0.859875
# 87    17.784527  57.489225     0.853458
# 88    22.124121  67.581261     0.851741
# 89    18.000000  56.450000     0.850000
# 90    20.333333  69.533333     0.846667
# 91    18.150187  56.858355     0.844951
# 92    20.282097  63.892568     0.801211
# 93    17.500000  55.350000     0.795000
# 94    23.263545  56.620246     0.757765
# 95    17.082938  54.967378     0.719214
# 96    26.500000  62.250000     0.715000
# 97    18.981233  57.370905     0.644631
# 98    19.693603  50.155892     0.630404
# 99    19.000000  42.950000     0.485000

# %% [markdown]
# ### ESL ONE COLOGNE Bracket
#
# <div align="center"><img src="../images/ESL One Cologne-Group A.png" style="width:500px;height:300px"> <img src="../images/ESL One Cologne-Group B.png" style="width:500px;height:300px"></div>
#
# <img src="../images/ESL One Cologne-Teams.png" class="center" style="width:600px;height:600px">
#
# Top teams from each upper bracket advances to semi-finals. The losers of the upper bracket finals play in the quarterfinals. Top teams from each lower bracket advances to quarterfinals. Teams that lose in the first round player teams from the same side of their bracket in the lower bracket. Teams in the upper bracket that lose in the second round play on the opposite side of the lower bracket. All teams starting on a particular upper bracket will only play teams of the bracket until the playoffs (quarters/semis).

# %% [markdown]
# ## Post Analysis

# %% [markdown]
# Fantasy system uses an average of a players pts when that player does not play during a particular round. This means that if your player bows out early, whatever their average pts was across the rounds that they played, gets added to your total score on each of the subsequent rounds. If one of your players advances and does not have to play a round (advances to the finals of the upper bracket and makes it directly to the semis), they also carry their average across those non-played rounds. **All in all, this means that you want to choose players that will make the semi's directly because you are more likely to be guaranteed points with less variation.**
#
# I'll simulate the tournament next time to get the most likely outcomes for the tournament and prioritize players that are on teams that are likely to make the upper bracket finals and/or the semis. I will also take the final ratings of each player from the tourny to create a dataset to train on the final ratings given pre-match aggregate features.
#
# I need to make sure to version my data.
